# %%
# !pip install ultralytics

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 3. Credenciales Kaggle
import os, json
from dotenv import load_dotenv
load_dotenv('/content/drive/MyDrive/CAELESTIS/.env')
os.makedirs('/root/.kaggle', exist_ok=True)
with open('/root/.kaggle/kaggle.json', 'w') as f:
    json.dump({"username": os.getenv("KAGGLE_USERNAME"), "key": os.getenv("KAGGLE_KEY")}, f)
os.chmod('/root/.kaggle/kaggle.json', 0o600)

# %%
# !kaggle datasets download -d piratinskii/astronomical-object-detection --unzip -p /content/cosmica
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/piratinskii/astronomical-object-detection
# License(s): unknown
# ...
# 100% 1.04G/1.04G [00:04<00:00, 245MB/s]

# %%
from ultralytics import YOLO
model = YOLO('/content/drive/MyDrive/CAELESTIS/runs/caelestis_v1/weights/best.pt')
print("Modelo cargado ✓")
# Out:
# Modelo cargado ✓

# %%
# Evaluación final del modelo en el conjunto de test
model = YOLO('/content/drive/MyDrive/CAELESTIS/runs/caelestis_v1/weights/best.pt')
metrics = model.val(data='/content/cosmica/yolov11_balanced/dataset.yaml', split='test')
# Out:
# Ultralytics 8.4.41 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 73 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1256.3±595.2 MB/s, size: 41.2 KB)
# val: Scanning /content/cosmica/yolov11_balanced/test/labels.cache... 1948 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1948/1948 680.9Mit/s 0.0s
# val: /content/cosmica/yolov11_balanced/test/images/orion_nebula1_jpg.rf.4887bdde492c1a76d201b4dd5a0d7dda.jpg: 1 duplicate labels removed
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 574, len(boxes) = 3635. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 12% ━─────────── 15/122 5.2it/s 4.3s<20.5s
